# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import numpy as np
import pandas as pd

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314 entries, 0 to 313
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            313 non-null    datetime64[ns]
#  1   City of London        314 non-null    object
#  2   Barking & Dagenham    314 non-null    object
#  3   Barnet                314 non-null    object
#  4   Bexley                314 non-null    object
#  5   Brent                 314 non-null    object
#  6   Bromley               314 non-null    object
#  7   Camden                314 non-null    object
#  8   Croydon               314 non-null    object
#  9   Ealing                314 non-null    object
#  10  Enfield               314 non-null    object
#  11  Greenwich             314 non-null    object
#  12  Hackney               314 non-null    object
#  13  Hammersmith & Fulham  314 non-null    object
#  14  Haringey              314 non-null    object
#  15  Harrow                314 non-null    object
#  16  Havering              314 non-null    object
#  17  Hillingdon            314 non-null    object
#  18  Hounslow              314 non-null    object
#  19  Islington             314 non-null    object
#  20  Kensington & Chelsea  314 non-null    object
#  21  Kingston upon Thames  314 non-null    object
#  22  Lambeth               314 non-null    object
#  23  Lewisham              314 non-null    object
#  24  Merton                314 non-null    object
#  25  Newham                314 non-null    object
#  26  Redbridge             314 non-null    object
#  27  Richmond upon Thames  314 non-null    object
#  28  Southwark             314 non-null    object
#  29  Sutton                314 non-null    object
#  30  Tower Hamlets         314 non-null    object
#  31  Waltham Forest        314 non-null    object
#  32  Wandsworth            314 non-null    object
#  33  Westminster           314 non-null    object
#  34  Unnamed: 34           0 non-null      float64
#  35  Inner London          314 non-null    object
#  36  Outer London          314 non-null    object
#  37  Unnamed: 37           0 non-null      float64
#  38  NORTH EAST            314 non-null    object
#  39  NORTH WEST            314 non-null    object
#  40  YORKS & THE HUMBER    314 non-null    object
#  41  EAST MIDLANDS         314 non-null    object
#  42  WEST MIDLANDS         314 non-null    object
#  43  EAST OF ENGLAND       314 non-null    object
#  44  LONDON                314 non-null    object
#  45  SOUTH EAST            314 non-null    object
#  46  SOUTH WEST            314 non-null    object
#  47  Unnamed: 47           0 non-null      float64
#  48  England               314 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(45)
# memory usage: 120.3+ KB

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# 0          E12000003     E12000004     E12000005       E12000006  E12000007
# 1            44803.4       45544.5       48527.5         56701.6    74435.8
# 2            44528.8       46051.6       49341.3         56593.6    72777.9
# 3            45200.5       45383.8       49442.2         56171.2    73896.8
# 4            45614.3       46124.2       49455.9         56567.9    74455.3
#
#   SOUTH EAST SOUTH WEST Unnamed: 47    England
# 0  E12000008  E12000009         NaN  E92000001
# 1    64018.9    54705.2         NaN    53202.8
# 2      63715    54356.1         NaN    53096.2
# 3    64113.6    53583.1         NaN    53201.3
# 4    64623.2      54786         NaN    53590.9
#
# [5 rows x 49 columns]

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties = properties.transpose()
properties
# Out:
#                             0                    1                    2    \
# Unnamed: 0                  NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London        E09000001                91449              82202.8
# Barking & Dagenham    E09000002              50460.2              51085.8
# Barnet                E09000003              93284.5              93190.2
# Bexley                E09000004              64958.1              64787.9
# Brent                 E09000005              71306.6              72022.3
# Bromley               E09000006              81671.5              81657.6
# Camden                E09000007               120933               119509
# Croydon               E09000008              69158.2              68951.1
# Ealing                E09000009              79885.9              80897.1
# Enfield               E09000010              72514.7              73155.2
# Greenwich             E09000011              62300.1              60993.3
# Hackney               E09000012              61296.5              63187.1
# Hammersmith & Fulham  E09000013               124903               122088
# Haringey              E09000014              76287.6              78901.2
# Harrow                E09000015              84769.5              83396.1
# Havering              E09000016              68000.1              69393.5
# Hillingdon            E09000017              73834.8              75031.1
# Hounslow              E09000018              72231.7              71051.6
# Islington             E09000019              92516.5              94342.4
# Kensington & Chelsea  E09000020               182695               182345
# Kingston upon Thames  E09000021              80875.8              81230.1
# Lambeth               E09000022                67771              65381.5
# Lewisham              E09000023              60491.3              60869.3
# Merton                E09000024              82070.6              79982.7
# Newham                E09000025              53539.3              53153.9
# Redbridge             E09000026              72189.6              72141.6
# Richmond upon Thames  E09000027               109326               111103
# Southwark             E09000028              67885.2              64799.1
# Sutton                E09000029                71537              70893.2
# Tower Hamlets         E09000030              59865.2              62318.5
# Waltham Forest        E09000031              61319.4              60252.1
# Wandsworth            E09000032                88559                88641
# Westminster           E09000033               133025               131468
# Unnamed: 34                 NaN                  NaN                  NaN
# Inner London          E13000001                78252              75885.7
# Outer London          E13000002              72958.8              72937.9
# Unnamed: 37                 NaN                  NaN                  NaN
# NORTH EAST            E12000001              42076.4                42572
# NORTH WEST            E12000002              43958.5              43925.4
# YORKS & THE HUMBER    E12000003              44803.4              44528.8
# EAST MIDLANDS         E12000004              45544.5              46051.6
# WEST MIDLANDS         E12000005              48527.5              49341.3
# EAST OF ENGLAND       E12000006              56701.6              56593.6
# LONDON                E12000007              74435.8              72777.9
# SOUTH EAST            E12000008              64018.9                63715
# SOUTH WEST            E12000009              54705.2              54356.1
# Unnamed: 47                 NaN                  NaN                  NaN
# England               E92000001              53202.8              53096.2
#
#                                       3                    4    \
# Unnamed: 0            1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London                    79120.7              77101.2
# Barking & Dagenham                  51269              53133.5
# Barnet                            92247.5              90762.9
# Bexley                            64367.5              64277.7
# Brent                             72015.8              72965.6
# Bromley                           81449.3              81124.4
# Camden                             120282               120098
# Croydon                           68712.4                68610
# Ealing                            81379.9              82188.9
# Enfield                           72190.4              71442.9
# Greenwich                         61377.8              61927.7
# Hackney                           63593.3              65139.6
# Hammersmith & Fulham               120636               121425
# Haringey                          78521.9              79545.6
# Harrow                            83416.2              83567.9
# Havering                            69368              69444.3
# Hillingdon                        74188.7              73911.4
# Hounslow                            72098              71890.3
# Islington                         93465.9              93344.5
# Kensington & Chelsea               182879               184177
# Kingston upon Thames              81111.5              81672.8
# Lambeth                           66336.5              66388.8
# Lewisham                            60288                59471
# Merton                            80661.7              79990.5
# Newham                            53458.3              54479.8
# Redbridge                         72501.4              72228.6
# Richmond upon Thames               107325               106875
# Southwark                         65763.3              63073.6
# Sutton                            70306.8              69411.9
# Tower Hamlets                     63938.7              66233.2
# Waltham Forest                    60871.1              60971.4
# Wandsworth                        87124.8                87026
# Westminster                        132260               133370
# Unnamed: 34                           NaN                  NaN
# Inner London                      76591.6              76851.6
# Outer London                      72714.5              72591.9
# Unnamed: 37                           NaN                  NaN
# NORTH EAST                        42369.7              42095.8
# NORTH WEST                        44434.9              44267.8
# YORKS & THE HUMBER                45200.5              45614.3
# EAST MIDLANDS                     45383.8              46124.2
# WEST MIDLANDS                     49442.2              49455.9
# EAST OF ENGLAND                   56171.2              56567.9
# LONDON                            73896.8              74455.3
# SOUTH EAST                        64113.6              64623.2
# SOUTH WEST                        53583.1                54786
# Unnamed: 47                           NaN                  NaN
# England                           53201.3              53590.9
#
#                                       5                    6    \
# Unnamed: 0            1995-05-01 00:00:00  1995-06-01 00:00:00
# City of London                    84409.1              94900.5
# Barking & Dagenham                53042.2              53700.3
# Barnet                              90258              90107.2
# Bexley                            63997.1              64252.3
# Brent                               73704              74310.5
# Bromley                           81542.6              82382.8
# Camden                             119929               121887
# Croydon                           68844.9              69052.5
# Ealing                            82077.1              81630.7
# Enfield                           70630.8              71348.3
# Greenwich                           63513              64751.6
# Hackney                             66194              66921.2
# Hammersmith & Fulham               124434               126175
# Haringey                            79374              79956.4
# Harrow                            83853.7              84173.2
# Havering                          68534.5              68464.6
# Hillingdon                        73117.1                74005
# Hounslow                          72877.5              72331.1
# Islington                         94346.4              97428.9
# Kensington & Chelsea               191474               197266
# Kingston upon Thames              82123.5              82205.7
# Lambeth                           69035.1              68881.2
# Lewisham                          58551.4              58041.4
# Merton                              80874              80704.9
# Newham                              55804              56067.8
# Redbridge                         72366.6              72279.4
# Richmond upon Thames               107708               112865
# Southwark                         64420.5              64155.8
# Sutton                            69759.2              70125.2
# Tower Hamlets                     66432.9              66232.2
# Waltham Forest                    61494.2              61547.8
# Wandsworth                        86518.1              88114.3
# Westminster                        133911               134562
# Unnamed: 34                           NaN                  NaN
# Inner London                      79129.2              79969.2
# Outer London                        72753              73189.4
# Unnamed: 37                           NaN                  NaN
# NORTH EAST                        43266.5              42315.3
# NORTH WEST                        44223.6                44113
# YORKS & THE HUMBER                  44831              45392.6
# EAST MIDLANDS                       45878                45680
# WEST MIDLANDS                     50369.7              50100.4
# EAST OF ENGLAND                   56479.8              56288.9
# LONDON                              75432              75606.2
# SOUTH EAST                        64530.4                65511
# SOUTH WEST                        54698.8              54420.2
# Unnamed: 47                           NaN                  NaN
# England                           53678.2              53735.2
#
#                                       7                    8    \
# Unnamed: 0            1995-07-01 00:00:00  1995-08-01 00:00:00
# City of London                     110128               112329
# Barking & Dagenham                52113.1              52232.2
# Barnet                            91441.2              92361.3
# Bexley                            63722.7              64432.6
# Brent                               74127                73547
# Bromley                           82898.5              82054.4
# Camden                             124028               125530
# Croydon                           69142.5              68993.4
# Ealing                            82352.2              82706.7
# Enfield                           71837.5              72237.9
# Greenwich                         65486.3              65076.4
# Hackney                           68390.8              68096.8
# Hammersmith & Fulham               124382               123625
# Haringey                          80746.3              81217.7
# Harrow                            84226.7              84430.6
# Havering                          68680.8              69023.4
# Hillingdon                        74671.1              74967.9
# Hounslow                          73717.8              74479.9
# Islington                         98976.1              98951.2
# Kensington & Chelsea               197963               198037
# Kingston upon Thames              82525.8              83342.8
# Lambeth                           69608.7                68840
# Lewisham                          58126.4              58151.3
# Merton                            81055.9              80781.1
# Newham                            55458.3              54709.4
# Redbridge                         72880.8              73275.2
# Richmond upon Thames               114657               112320
# Southwark                         67024.7              65525.9
# Sutton                            70789.6              69958.4
# Tower Hamlets                     64692.2              63472.3
# Waltham Forest                    61933.5              61916.4
# Wandsworth                        89830.6              90560.7
# Westminster                        133450               136582
# Unnamed: 34                           NaN                  NaN
# Inner London                      80550.5              80597.6
# Outer London                      73665.9              73691.1
# Unnamed: 37                           NaN                  NaN
# NORTH EAST                        43287.7              41899.1
# NORTH WEST                        44109.6              44193.7
# YORKS & THE HUMBER                  45535              45111.5
# EAST MIDLANDS                     46037.7              45922.5
# WEST MIDLANDS                       49860              49598.5
# EAST OF ENGLAND                   57242.3              56732.4
# LONDON                            75984.2              75529.3
# SOUTH EAST                        65224.9              64851.6
# SOUTH WEST                        54265.9              54365.7
# Unnamed: 47                           NaN                  NaN
# England                           53900.6              53600.3
#
#                                       9    ...                  304  \
# Unnamed: 0            1995-09-01 00:00:00  ...  2020-04-01 00:00:00
# City of London                     104473  ...               920444
# Barking & Dagenham                51471.6  ...               293603
# Barnet                            93273.1  ...               526689
# Bexley                            64509.5  ...               341553
# Brent                             73789.5  ...               470601
# Bromley                           81440.4  ...               433426
# Camden                             120597  ...               862077
# Croydon                           69393.5  ...               370032
# Ealing                            82011.1  ...               480314
# Enfield                           71725.2  ...               395240
# Greenwich                         63996.8  ...               395917
# Hackney                           68752.5  ...               579285
# Hammersmith & Fulham               123094  ...               698951
# Haringey                          82142.9  ...               544722
# Harrow                              83607  ...               451482
# Havering                          68108.2  ...               369485
# Hillingdon                        73843.6  ...               403517
# Hounslow                          74426.7  ...               401334
# Islington                         99582.6  ...               642190
# Kensington & Chelsea               197048  ...          1.36651e+06
# Kingston upon Thames                85111  ...               486367
# Lambeth                           70155.8  ...               503116
# Lewisham                            58743  ...               412995
# Merton                            80824.7  ...               511327
# Newham                            54585.5  ...               360609
# Redbridge                           73204  ...               419057
# Richmond upon Thames               110425  ...               665144
# Southwark                           63467  ...               500245
# Sutton                            69937.4  ...               376824
# Tower Hamlets                     62177.6  ...               470444
# Waltham Forest                    61548.2  ...               440821
# Wandsworth                        91373.7  ...               612598
# Westminster                        135993  ...          1.02679e+06
# Unnamed: 34                           NaN  ...                  NaN
# Inner London                      80402.9  ...               581017
# Outer London                      73454.4  ...               425810
# Unnamed: 37                           NaN  ...                  NaN
# NORTH EAST                        41850.9  ...               123259
# NORTH WEST                        44088.1  ...               163863
# YORKS & THE HUMBER                44837.9  ...               160235
# EAST MIDLANDS                     45771.7  ...               196252
# WEST MIDLANDS                     49319.7  ...               195119
# EAST OF ENGLAND                   56259.3  ...               290855
# LONDON                            74940.8  ...               475226
# SOUTH EAST                        64352.5  ...               324559
# SOUTH WEST                          54244  ...               256591
# Unnamed: 47                           NaN  ...                  NaN
# England                           53309.2  ...               246476
#
#                                       305                  306  \
# Unnamed: 0            2020-05-01 00:00:00  2020-06-01 00:00:00
# City of London                     918209               882872
# Barking & Dagenham                 293816               300526
# Barnet                             526033               518175
# Bexley                             339353               340893
# Brent                              482808               484160
# Bromley                            425300               425444
# Camden                             855338               837719
# Croydon                            373805               372414
# Ealing                             473283               463424
# Enfield                            391460               385347
# Greenwich                          392507               387218
# Hackney                            576964               571464
# Hammersmith & Fulham               680111               718768
# Haringey                           549865               546376
# Harrow                             445417               441942
# Havering                           367940               371148
# Hillingdon                         407142               403039
# Hounslow                           396578               394693
# Islington                          630653               641492
# Kensington & Chelsea          1.35341e+06          1.30097e+06
# Kingston upon Thames               482372               478540
# Lambeth                            513274               520303
# Lewisham                           416638               422939
# Merton                             515916               519174
# Newham                             363515               371624
# Redbridge                          418540               412781
# Richmond upon Thames               688187               701625
# Southwark                          516452               509473
# Sutton                             371896               371088
# Tower Hamlets                      460079               445197
# Waltham Forest                     444103               447790
# Wandsworth                         607048               596641
# Westminster                        944550               957831
# Unnamed: 34                           NaN                  NaN
# Inner London                       577820               576729
# Outer London                       425045               423808
# Unnamed: 37                           NaN                  NaN
# NORTH EAST                         127066               128964
# NORTH WEST                         164234               168963
# YORKS & THE HUMBER                 164927               168096
# EAST MIDLANDS                      194742               199049
# WEST MIDLANDS                      198336               202038
# EAST OF ENGLAND                    290097               291578
# LONDON                             470394               478922
# SOUTH EAST                         321421               322172
# SOUTH WEST                         255487               259493
# Unnamed: 47                           NaN                  NaN
# England                            247025               250851
#
#                                       307                  308  \
# Unnamed: 0            2020-07-01 00:00:00  2020-08-01 00:00:00
# City of London                     786627               827659
# Barking & Dagenham                 304556               304924
# Barnet                             523280               529660
# Bexley                             344091               346680
# Brent                              482303               497729
# Bromley                            428557               433423
# Camden                             807904               824742
# Croydon                            377278               374030
# Ealing                             466117               483810
# Enfield                            386065               397145
# Greenwich                          386101               389491
# Hackney                            584128               584804
# Hammersmith & Fulham               748437               758825
# Haringey                           547778               565432
# Harrow                             445805               452524
# Havering                           373192               375067
# Hillingdon                         408573               410161
# Hounslow                           394813               407761
# Islington                          656971               678741
# Kensington & Chelsea          1.32105e+06          1.34435e+06
# Kingston upon Thames               484775               497936
# Lambeth                            538635               538243
# Lewisham                           422336               421910
# Merton                             524383               528417
# Newham                             375328               374037
# Redbridge                          417394               420140
# Richmond upon Thames               695228               688624
# Southwark                          508674               506554
# Sutton                             373184               378301
# Tower Hamlets                      444565               454850
# Waltham Forest                     443867               449510
# Wandsworth                         597441               611665
# Westminster                        917264               981248
# Unnamed: 34                           NaN                  NaN
# Inner London                       579694               588876
# Outer London                       426273               431209
# Unnamed: 37                           NaN                  NaN
# NORTH EAST                         130808               131490
# NORTH WEST                         171215               173942
# YORKS & THE HUMBER                 169204               171634
# EAST MIDLANDS                      200701               201351
# WEST MIDLANDS                      203670               205466
# EAST OF ENGLAND                    292738               296928
# LONDON                             483146               488557
# SOUTH EAST                         325886               329550
# SOUTH WEST                         264554               265726
# Unnamed: 47                           NaN                  NaN
# England                            253482               256135
#
#                                       309                  310  \
# Unnamed: 0            2020-09-01 00:00:00  2020-10-01 00:00:00
# City of London                     802639               841259
# Barking & Dagenham                 302467               305283
# Barnet                             535671               532217
# Bexley                             344895               345812
# Brent                              519982               524109
# Bromley                            435694               440852
# Camden                             835801               833114
# Croydon                            376580               378475
# Ealing                             490242               494603
# Enfield                            400193               407267
# Greenwich                          401498               402302
# Hackney                            609438               595220
# Hammersmith & Fulham               740695               726078
# Haringey                           572567               588749
# Harrow                             455065               459219
# Havering                           373052               371515
# Hillingdon                         411580               417771
# Hounslow                           416328               420997
# Islington                          693437               689956
# Kensington & Chelsea           1.3557e+06          1.32237e+06
# Kingston upon Thames               503436               504706
# Lambeth                            546152               547062
# Lewisham                           427626               434871
# Merton                             527288               543583
# Newham                             371711               377062
# Redbridge                          427223               432256
# Richmond upon Thames               687669               688764
# Southwark                          511889               517374
# Sutton                             383314               386439
# Tower Hamlets                      464114               473284
# Waltham Forest                     456631               466749
# Wandsworth                         631196               630693
# Westminster                        947646               917690
# Unnamed: 34                           NaN                  NaN
# Inner London                       596031               597237
# Outer London                       435117               438607
# Unnamed: 37                           NaN                  NaN
# NORTH EAST                         135672               136090
# NORTH WEST                         174735               178929
# YORKS & THE HUMBER                 172440               176337
# EAST MIDLANDS                      203063               206667
# WEST MIDLANDS                      208175               210814
# EAST OF ENGLAND                    301673               302106
# LONDON                             494731               491315
# SOUTH EAST                         333656               335962
# SOUTH WEST                         271698               273585
# Unnamed: 47                           NaN                  NaN
# England                            259402               262065
#
#                                       311                  312  \
# Unnamed: 0            2020-11-01 00:00:00  2020-12-01 00:00:00
# City of London                     785325               816515
# Barking & Dagenham                 307227               312098
# Barnet                             533279               534576
# Bexley                             349116               355022
# Brent                              516904               498291
# Bromley                            453183               462649
# Camden                             833794               819718
# Croydon                            383438               385370
# Ealing                             503837               506894
# Enfield                            406913               412179
# Greenwich                          408671               410005
# Hackney                            600850               592948
# Hammersmith & Fulham               739174               718468
# Haringey                           583768               586612
# Harrow                             466582               475374
# Havering                           374960               378460
# Hillingdon                         421110               430236
# Hounslow                           424627               422112
# Islington                          674970               666842
# Kensington & Chelsea          1.33168e+06          1.34848e+06
# Kingston upon Thames               505802               507666
# Lambeth                            547169               538052
# Lewisham                           441248               440931
# Merton                             554415               561128
# Newham                             377207               384162
# Redbridge                          440527               446786
# Richmond upon Thames               696335               704749
# Southwark                          527020               539035
# Sutton                             391661               395670
# Tower Hamlets                      473184               471023
# Waltham Forest                     470832               475088
# Wandsworth                         629209               617669
# Westminster                        919047               915576
# Unnamed: 34                           NaN                  NaN
# Inner London                       598862               596334
# Outer London                       443557               447608
# Unnamed: 37                           NaN                  NaN
# NORTH EAST                         138412               139960
# NORTH WEST                         180061               183036
# YORKS & THE HUMBER                 180154               181792
# EAST MIDLANDS                      209196               212499
# WEST MIDLANDS                      212290               215328
# EAST OF ENGLAND                    303534               308460
# LONDON                             500360               500744
# SOUTH EAST                         340124               342038
# SOUTH WEST                         275496               279560
# Unnamed: 47                           NaN                  NaN
# England                            265010               268044
#
#                                       313
# Unnamed: 0            2021-01-01 00:00:00
# City of London                     781788
# Barking & Dagenham                 316257
# Barnet                             544918
# Bexley                             359197
# Brent                              519355
# Bromley                            465318
# Camden                             864668
# Croydon                            390093
# Ealing                             501151
# Enfield                            417343
# Greenwich                          411066
# Hackney                            599090
# Hammersmith & Fulham               745509
# Haringey                           622104
# Harrow                             475996
# Havering                           387744
# Hillingdon                         423124
# Hounslow                           429745
# Islington                          712428
# Kensington & Chelsea          1.31359e+06
# Kingston upon Thames               498102
# Lambeth                            542446
# Lewisham                           450161
# Merton                             551175
# Newham                             378023
# Redbridge                          461767
# Richmond upon Thames               723399
# Southwark                          535468
# Sutton                             385231
# Tower Hamlets                      457731
# Waltham Forest                     478186
# Wandsworth                         598547
# Westminster                        956658
# Unnamed: 34                           NaN
# Inner London                       600310
# Outer London                       450618
# Unnamed: 37                           NaN
# NORTH EAST                         138151
# NORTH WEST                         184234
# YORKS & THE HUMBER                 179248
# EAST MIDLANDS                      209927
# WEST MIDLANDS                      210454
# EAST OF ENGLAND                    310639
# LONDON                             501320
# SOUTH EAST                         342420
# SOUTH WEST                         274648
# Unnamed: 47                           NaN
# England                            266532
#
# [49 rows x 314 columns]

# %%
properties.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
properties = properties.reset_index()
properties.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
# 2              53700.3              52113.1              52232.2  ...
# 3              90107.2              91441.2              92361.3  ...
# 4              64252.3              63722.7              64432.6  ...
#
#                    304                  305                  306  \
# 0  2020-04-01 00:00:00  2020-05-01 00:00:00  2020-06-01 00:00:00
# 1               920444               918209               882872
# 2               293603               293816               300526
# 3               526689               526033               518175
# 4               341553               339353               340893
#
#                    307                  308                  309  \
# 0  2020-07-01 00:00:00  2020-08-01 00:00:00  2020-09-01 00:00:00
# 1               786627               827659               802639
# 2               304556               304924               302467
# 3               523280               529660               535671
# 4               344091               346680               344895
#
#                    310                  311                  312  \
# 0  2020-10-01 00:00:00  2020-11-01 00:00:00  2020-12-01 00:00:00
# 1               841259               785325               816515
# 2               305283               307227               312098
# 3               532217               533279               534576
# 4               345812               349116               355022
#
#                    313
# 0  2021-01-01 00:00:00
# 1               781788
# 2               316257
# 3               544918
# 4               359197
#
# [5 rows x 315 columns]

# %%
properties.columns = properties.iloc[0]
properties.head()
# Out:
# 0          Unnamed: 0        NaN  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
# 2              53700.3              52113.1              52232.2  ...
# 3              90107.2              91441.2              92361.3  ...
# 4              64252.3              63722.7              64432.6  ...
#
# 0  2020-04-01 00:00:00  2020-05-01 00:00:00  2020-06-01 00:00:00  \
# 0  2020-04-01 00:00:00  2020-05-01 00:00:00  2020-06-01 00:00:00
# 1               920444               918209               882872
# 2               293603               293816               300526
# 3               526689               526033               518175
# 4               341553               339353               340893
#
# 0  2020-07-01 00:00:00  2020-08-01 00:00:00  2020-09-01 00:00:00  \
# 0  2020-07-01 00:00:00  2020-08-01 00:00:00  2020-09-01 00:00:00
# 1               786627               827659               802639
# 2               304556               304924               302467
# 3               523280               529660               535671
# 4               344091               346680               344895
#
# 0  2020-10-01 00:00:00  2020-11-01 00:00:00  2020-12-01 00:00:00  \
# 0  2020-10-01 00:00:00  2020-11-01 00:00:00  2020-12-01 00:00:00
# 1               841259               785325               816515
# 2               305283               307227               312098
# 3               532217               533279               534576
# 4               345812               349116               355022
#
# 0  2021-01-01 00:00:00
# 0  2021-01-01 00:00:00
# 1               781788
# 2               316257
# 3               544918
# 4               359197
#
# [5 rows x 315 columns]

# %%
properties = properties.drop(0)
properties.head()
# Out:
# 0          Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
# 3             92247.5             90762.9               90258
# 4             64367.5             64277.7             63997.1
# 5             72015.8             72965.6               73704
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# 2             53700.3             52113.1             52232.2  ...
# 3             90107.2             91441.2             92361.3  ...
# 4             64252.3             63722.7             64432.6  ...
# 5             74310.5               74127               73547  ...
#
# 0 2020-04-01 00:00:00 2020-05-01 00:00:00 2020-06-01 00:00:00  \
# 1              920444              918209              882872
# 2              293603              293816              300526
# 3              526689              526033              518175
# 4              341553              339353              340893
# 5              470601              482808              484160
#
# 0 2020-07-01 00:00:00 2020-08-01 00:00:00 2020-09-01 00:00:00  \
# 1              786627              827659              802639
# 2              304556              304924              302467
# 3              523280              529660              535671
# 4              344091              346680              344895
# 5              482303              497729              519982
#
# 0 2020-10-01 00:00:00 2020-11-01 00:00:00 2020-12-01 00:00:00  \
# 1              841259              785325              816515
# 2              305283              307227              312098
# 3              532217              533279              534576
# 4              345812              349116              355022
# 5              524109              516904              498291
#
# 0 2021-01-01 00:00:00
# 1              781788
# 2              316257
# 3              544918
# 4              359197
# 5              519355
#
# [5 rows x 315 columns]

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties = properties.rename(columns = {'Unnamed: 0':'London_Borough', pd.NaT: 'ID'})
properties.head()
# Out:
# 0      London_Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
# 3             92247.5             90762.9               90258
# 4             64367.5             64277.7             63997.1
# 5             72015.8             72965.6               73704
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# 2             53700.3             52113.1             52232.2  ...
# 3             90107.2             91441.2             92361.3  ...
# 4             64252.3             63722.7             64432.6  ...
# 5             74310.5               74127               73547  ...
#
# 0 2020-04-01 00:00:00 2020-05-01 00:00:00 2020-06-01 00:00:00  \
# 1              920444              918209              882872
# 2              293603              293816              300526
# 3              526689              526033              518175
# 4              341553              339353              340893
# 5              470601              482808              484160
#
# 0 2020-07-01 00:00:00 2020-08-01 00:00:00 2020-09-01 00:00:00  \
# 1              786627              827659              802639
# 2              304556              304924              302467
# 3              523280              529660              535671
# 4              344091              346680              344895
# 5              482303              497729              519982
#
# 0 2020-10-01 00:00:00 2020-11-01 00:00:00 2020-12-01 00:00:00  \
# 1              841259              785325              816515
# 2              305283              307227              312098
# 3              532217              533279              534576
# 4              345812              349116              355022
# 5              524109              516904              498291
#
# 0 2021-01-01 00:00:00
# 1              781788
# 2              316257
# 3              544918
# 4              359197
# 5              519355
#
# [5 rows x 315 columns]

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties.columns
# Out:
# Index([   'London_Borough',                'ID', 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2020-04-01 00:00:00, 2020-05-01 00:00:00, 2020-06-01 00:00:00,
#        2020-07-01 00:00:00, 2020-08-01 00:00:00, 2020-09-01 00:00:00,
#        2020-10-01 00:00:00, 2020-11-01 00:00:00, 2020-12-01 00:00:00,
#        2021-01-01 00:00:00],
#       dtype='object', name=0, length=315)

# %%
properties = pd.melt(properties, id_vars= ['London_Borough', 'ID'])
properties
# Out:
#            London_Borough         ID          0    value
# 0          City of London  E09000001 1995-01-01    91449
# 1      Barking & Dagenham  E09000002 1995-01-01  50460.2
# 2                  Barnet  E09000003 1995-01-01  93284.5
# 3                  Bexley  E09000004 1995-01-01  64958.1
# 4                   Brent  E09000005 1995-01-01  71306.6
# ...                   ...        ...        ...      ...
# 15019              LONDON  E12000007 2021-01-01   501320
# 15020          SOUTH EAST  E12000008 2021-01-01   342420
# 15021          SOUTH WEST  E12000009 2021-01-01   274648
# 15022         Unnamed: 47        NaN 2021-01-01      NaN
# 15023             England  E92000001 2021-01-01   266532
#
# [15024 rows x 4 columns]

# %%
properties = properties.rename(columns = {0: 'Month', 'value': 'Average_Price'})
properties.head()
# Out:
#        London_Borough         ID      Month Average_Price
# 0      City of London  E09000001 1995-01-01         91449
# 1  Barking & Dagenham  E09000002 1995-01-01       50460.2
# 2              Barnet  E09000003 1995-01-01       93284.5
# 3              Bexley  E09000004 1995-01-01       64958.1
# 4               Brent  E09000005 1995-01-01       71306.6

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_Price             object
# dtype: object

# %%
properties['Average_Price'] = pd.to_numeric(properties['Average_Price'])
properties.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_Price            float64
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
properties.count()
# Out:
# London_Borough    15024
# ID                14085
# Month             15024
# Average_Price     14085
# dtype: int64

# %%
properties['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
properties[properties['London_Borough'] == 'Unnamed: 34'].head()
# Out:
#     London_Borough   ID      Month  Average_Price
# 33     Unnamed: 34  NaN 1995-01-01            NaN
# 81     Unnamed: 34  NaN 1995-02-01            NaN
# 129    Unnamed: 34  NaN 1995-03-01            NaN
# 177    Unnamed: 34  NaN 1995-04-01            NaN
# 225    Unnamed: 34  NaN 1995-05-01            NaN

# %%
properties[properties['London_Borough'] == 'Unnamed: 37'].head()
# Out:
#     London_Borough   ID      Month  Average_Price
# 36     Unnamed: 37  NaN 1995-01-01            NaN
# 84     Unnamed: 37  NaN 1995-02-01            NaN
# 132    Unnamed: 37  NaN 1995-03-01            NaN
# 180    Unnamed: 37  NaN 1995-04-01            NaN
# 228    Unnamed: 37  NaN 1995-05-01            NaN

# %%
properties[properties['London_Borough'] == 'Unnamed: 47'].head()
# Out:
#     London_Borough   ID      Month  Average_Price
# 46     Unnamed: 47  NaN 1995-01-01            NaN
# 94     Unnamed: 47  NaN 1995-02-01            NaN
# 142    Unnamed: 47  NaN 1995-03-01            NaN
# 190    Unnamed: 47  NaN 1995-04-01            NaN
# 238    Unnamed: 47  NaN 1995-05-01            NaN

# %%
# drop Unnamed 34, 37, and 47
properties = properties.set_index('London_Borough')
properties = properties.drop(labels = ['Unnamed: 34', 'Unnamed: 37', 'Unnamed: 47'])

# %%
properties = properties.reset_index()
properties.head()
# Out:
#        London_Borough         ID      Month  Average_Price
# 0      City of London  E09000001 1995-01-01    91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2              Barnet  E09000003 1995-01-01    93284.51832
# 3              Bexley  E09000004 1995-01-01    64958.09036
# 4               Brent  E09000005 1995-01-01    71306.56698

# %%
# Check properties counts 
properties.count()
# Out:
# London_Borough    14085
# ID                14085
# Month             14085
# Average_Price     14085
# dtype: int64

# %%
#Check for rows with NAs as their value for ID
properties[properties['ID'].isna()]
# Out:
# Empty DataFrame
# Columns: [London_Borough, ID, Month, Average_Price]
# Index: []

# %%
NaNFreeDF1 = properties[properties['Average_Price'].notna()]
NaNFreeDF1.head(48)
# Out:
#           London_Borough         ID      Month  Average_Price
# 0         City of London  E09000001 1995-01-01    91448.98487
# 1     Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2                 Barnet  E09000003 1995-01-01    93284.51832
# 3                 Bexley  E09000004 1995-01-01    64958.09036
# 4                  Brent  E09000005 1995-01-01    71306.56698
# 5                Bromley  E09000006 1995-01-01    81671.47692
# 6                 Camden  E09000007 1995-01-01   120932.88810
# 7                Croydon  E09000008 1995-01-01    69158.16225
# 8                 Ealing  E09000009 1995-01-01    79885.89069
# 9                Enfield  E09000010 1995-01-01    72514.69096
# 10             Greenwich  E09000011 1995-01-01    62300.10169
# 11               Hackney  E09000012 1995-01-01    61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01   124902.86020
# 13              Haringey  E09000014 1995-01-01    76287.56947
# 14                Harrow  E09000015 1995-01-01    84769.52599
# 15              Havering  E09000016 1995-01-01    68000.13774
# 16            Hillingdon  E09000017 1995-01-01    73834.82964
# 17              Hounslow  E09000018 1995-01-01    72231.70537
# 18             Islington  E09000019 1995-01-01    92516.48557
# 19  Kensington & Chelsea  E09000020 1995-01-01   182694.83260
# 20  Kingston upon Thames  E09000021 1995-01-01    80875.84843
# 21               Lambeth  E09000022 1995-01-01    67770.98843
# 22              Lewisham  E09000023 1995-01-01    60491.26109
# 23                Merton  E09000024 1995-01-01    82070.61330
# 24                Newham  E09000025 1995-01-01    53539.31919
# 25             Redbridge  E09000026 1995-01-01    72189.58437
# 26  Richmond upon Thames  E09000027 1995-01-01   109326.12450
# 27             Southwark  E09000028 1995-01-01    67885.20344
# 28                Sutton  E09000029 1995-01-01    71536.97357
# 29         Tower Hamlets  E09000030 1995-01-01    59865.18995
# 30        Waltham Forest  E09000031 1995-01-01    61319.44913
# 31            Wandsworth  E09000032 1995-01-01    88559.04381
# 32           Westminster  E09000033 1995-01-01   133025.27720
# 33          Inner London  E13000001 1995-01-01    78251.97650
# 34          Outer London  E13000002 1995-01-01    72958.79836
# 35            NORTH EAST  E12000001 1995-01-01    42076.35411
# 36            NORTH WEST  E12000002 1995-01-01    43958.48001
# 37    YORKS & THE HUMBER  E12000003 1995-01-01    44803.42878
# 38         EAST MIDLANDS  E12000004 1995-01-01    45544.52227
# 39         WEST MIDLANDS  E12000005 1995-01-01    48527.52339
# 40       EAST OF ENGLAND  E12000006 1995-01-01    56701.59610
# 41                LONDON  E12000007 1995-01-01    74435.76052
# 42            SOUTH EAST  E12000008 1995-01-01    64018.87894
# 43            SOUTH WEST  E12000009 1995-01-01    54705.15790
# 44               England  E92000001 1995-01-01    53202.77128
# 45        City of London  E09000001 1995-02-01    82202.77314
# 46    Barking & Dagenham  E09000002 1995-02-01    51085.77983
# 47                Barnet  E09000003 1995-02-01    93190.16963

# %%
NaNFreeDF1.count()
# Out:
# London_Borough    14085
# ID                14085
# Month             14085
# Average_Price     14085
# dtype: int64

# %%
NaNFreeDF2 = properties.dropna()
NaNFreeDF2.head(48)
# Out:
#           London_Borough         ID      Month  Average_Price
# 0         City of London  E09000001 1995-01-01    91448.98487
# 1     Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2                 Barnet  E09000003 1995-01-01    93284.51832
# 3                 Bexley  E09000004 1995-01-01    64958.09036
# 4                  Brent  E09000005 1995-01-01    71306.56698
# 5                Bromley  E09000006 1995-01-01    81671.47692
# 6                 Camden  E09000007 1995-01-01   120932.88810
# 7                Croydon  E09000008 1995-01-01    69158.16225
# 8                 Ealing  E09000009 1995-01-01    79885.89069
# 9                Enfield  E09000010 1995-01-01    72514.69096
# 10             Greenwich  E09000011 1995-01-01    62300.10169
# 11               Hackney  E09000012 1995-01-01    61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01   124902.86020
# 13              Haringey  E09000014 1995-01-01    76287.56947
# 14                Harrow  E09000015 1995-01-01    84769.52599
# 15              Havering  E09000016 1995-01-01    68000.13774
# 16            Hillingdon  E09000017 1995-01-01    73834.82964
# 17              Hounslow  E09000018 1995-01-01    72231.70537
# 18             Islington  E09000019 1995-01-01    92516.48557
# 19  Kensington & Chelsea  E09000020 1995-01-01   182694.83260
# 20  Kingston upon Thames  E09000021 1995-01-01    80875.84843
# 21               Lambeth  E09000022 1995-01-01    67770.98843
# 22              Lewisham  E09000023 1995-01-01    60491.26109
# 23                Merton  E09000024 1995-01-01    82070.61330
# 24                Newham  E09000025 1995-01-01    53539.31919
# 25             Redbridge  E09000026 1995-01-01    72189.58437
# 26  Richmond upon Thames  E09000027 1995-01-01   109326.12450
# 27             Southwark  E09000028 1995-01-01    67885.20344
# 28                Sutton  E09000029 1995-01-01    71536.97357
# 29         Tower Hamlets  E09000030 1995-01-01    59865.18995
# 30        Waltham Forest  E09000031 1995-01-01    61319.44913
# 31            Wandsworth  E09000032 1995-01-01    88559.04381
# 32           Westminster  E09000033 1995-01-01   133025.27720
# 33          Inner London  E13000001 1995-01-01    78251.97650
# 34          Outer London  E13000002 1995-01-01    72958.79836
# 35            NORTH EAST  E12000001 1995-01-01    42076.35411
# 36            NORTH WEST  E12000002 1995-01-01    43958.48001
# 37    YORKS & THE HUMBER  E12000003 1995-01-01    44803.42878
# 38         EAST MIDLANDS  E12000004 1995-01-01    45544.52227
# 39         WEST MIDLANDS  E12000005 1995-01-01    48527.52339
# 40       EAST OF ENGLAND  E12000006 1995-01-01    56701.59610
# 41                LONDON  E12000007 1995-01-01    74435.76052
# 42            SOUTH EAST  E12000008 1995-01-01    64018.87894
# 43            SOUTH WEST  E12000009 1995-01-01    54705.15790
# 44               England  E92000001 1995-01-01    53202.77128
# 45        City of London  E09000001 1995-02-01    82202.77314
# 46    Barking & Dagenham  E09000002 1995-02-01    51085.77983
# 47                Barnet  E09000003 1995-02-01    93190.16963

# %%
NaNFreeDF2.count()
# Out:
# London_Borough    14085
# ID                14085
# Month             14085
# Average_Price     14085
# dtype: int64

# %%
NaNFreeDF2['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Inner London',
#        'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'England'], dtype=object)

# %%
print(properties.shape)
print(NaNFreeDF1.shape)
print(NaNFreeDF2.shape)
# Out:
# (14085, 4)
# (14085, 4)
# (14085, 4)

# %%
#Remove non-boroughs
nonBoroughs = ['Inner London', 'Outer London', 
               'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 
               'EAST MIDLANDS', 'WEST MIDLANDS',
              'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 
              'SOUTH WEST', 'England']

# %%
NaNFreeDF2 = NaNFreeDF2[~NaNFreeDF2.London_Borough.isin(nonBoroughs)]
NaNFreeDF2.head()
# Out:
#        London_Borough         ID      Month  Average_Price
# 0      City of London  E09000001 1995-01-01    91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2              Barnet  E09000003 1995-01-01    93284.51832
# 3              Bexley  E09000004 1995-01-01    64958.09036
# 4               Brent  E09000005 1995-01-01    71306.56698

# %%
# Create final DATAFRAME!
df = NaNFreeDF2

# %%
df.head(20)
# Out:
#           London_Borough         ID      Month  Average_Price
# 0         City of London  E09000001 1995-01-01    91448.98487
# 1     Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2                 Barnet  E09000003 1995-01-01    93284.51832
# 3                 Bexley  E09000004 1995-01-01    64958.09036
# 4                  Brent  E09000005 1995-01-01    71306.56698
# 5                Bromley  E09000006 1995-01-01    81671.47692
# 6                 Camden  E09000007 1995-01-01   120932.88810
# 7                Croydon  E09000008 1995-01-01    69158.16225
# 8                 Ealing  E09000009 1995-01-01    79885.89069
# 9                Enfield  E09000010 1995-01-01    72514.69096
# 10             Greenwich  E09000011 1995-01-01    62300.10169
# 11               Hackney  E09000012 1995-01-01    61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01   124902.86020
# 13              Haringey  E09000014 1995-01-01    76287.56947
# 14                Harrow  E09000015 1995-01-01    84769.52599
# 15              Havering  E09000016 1995-01-01    68000.13774
# 16            Hillingdon  E09000017 1995-01-01    73834.82964
# 17              Hounslow  E09000018 1995-01-01    72231.70537
# 18             Islington  E09000019 1995-01-01    92516.48557
# 19  Kensington & Chelsea  E09000020 1995-01-01   182694.83260

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10329 entries, 0 to 14072
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   London_Borough  10329 non-null  object
#  1   ID              10329 non-null  object
#  2   Month           10329 non-null  datetime64[ns]
#  3   Average_Price   10329 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 403.5+ KB

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
camden_prices = df[df['London_Borough'] == 'Camden']
ax = camden_prices.plot(kind ='line', x = 'Month', y='Average_Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
# extract the year from every value in our Month column (to limit data points becasue 300 is more than needed)
df['Year'] = df['Month'].apply(lambda t: t.year)
df.tail()
# Out:
#        London_Borough         ID      Month  Average_Price  Year
# 14068          Sutton  E09000029 2021-01-01    385231.0363  2021
# 14069   Tower Hamlets  E09000030 2021-01-01    457731.2978  2021
# 14070  Waltham Forest  E09000031 2021-01-01    478186.2335  2021
# 14071      Wandsworth  E09000032 2021-01-01    598546.6746  2021
# 14072     Westminster  E09000033 2021-01-01    956658.3861  2021

# %%
dfg = df.groupby(by=['London_Borough', 'Year']).mean()
dfg.sample(10)
# Out:
#                            Average_Price
# London_Borough       Year
# Kingston upon Thames 2006  264667.037392
# Greenwich            2011  229295.398225
# Islington            2020  663496.610883
# Hounslow             2008  262945.495542
# Richmond upon Thames 2011  434537.173125
# Sutton               2016  365303.130833
# Barnet               2021  544918.160100
# City of London       2014  709385.487275
# Havering             1999   92889.340459
# Kingston upon Thames 2005  251156.254508

# %%
dfg = dfg.reset_index()
dfg.head()
# Out:
#        London_Borough  Year  Average_Price
# 0  Barking & Dagenham  1995   51817.969390
# 1  Barking & Dagenham  1996   51718.192690
# 2  Barking & Dagenham  1997   55974.262309
# 3  Barking & Dagenham  1998   60285.821083
# 4  Barking & Dagenham  1999   65320.934441

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
def create_price_ratio(d):
    y1998 = float(d['Average_Price'][d['Year']==1998])
    y2018 = float(d['Average_Price'][d['Year']==2018])
    ratio = [y2018/y1998]
    return ratio

# %%
create_price_ratio(dfg[dfg['London_Borough']=='Barking & Dagenham'])
# Out:
# [4.89661861291754]

# %%
final = {}

# %%
for b in dfg['London_Borough'].unique():
    borough = dfg[dfg['London_Borough'] == b]
    final[b] = create_price_ratio(borough)
print(final)
# Out:
# {'Barking & Dagenham': [4.89661861291754], 'Barnet': [4.358195917538044], 'Bexley': [4.248977046127877], 'Brent': [4.8945544971392865], 'Bromley': [4.0947846853338765], 'Camden': [4.935353408884261], 'City of London': [5.301620377587609], 'Croydon': [4.201100280024767], 'Ealing': [4.311450902121834], 'Enfield': [4.26347158349581], 'Greenwich': [4.763036347329193], 'Hackney': [6.198285561008662], 'Hammersmith & Fulham': [4.137798101936229], 'Haringey': [5.134624964136042], 'Harrow': [4.0591964329643195], 'Havering': [4.325230371335308], 'Hillingdon': [4.2002730803844575], 'Hounslow': [3.976409106143329], 'Islington': [4.844048012802298], 'Kensington & Chelsea': [5.082465066092464], 'Kingston upon Thames': [4.270549521484271], 'Lambeth': [4.957751163514063], 'Lewisham': [5.449221041059685], 'Merton': [4.741273313294604], 'Newham': [5.305390437201879], 'Redbridge': [4.471182006097364], 'Richmond upon Thames': [4.005161895721457], 'Southwark': [5.516485302379376], 'Sutton': [4.118522608573157], 'Tower Hamlets': [4.62670104006116], 'Waltham Forest': [5.83475580932281], 'Wandsworth': [4.757709347739269], 'Westminster': [5.353565392605413]}

# %%
df_ratios = pd.DataFrame(final)

# %%
df_ratios.head()
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            4.896619  4.358196  4.248977  4.894554  4.094785  4.935353
#
#    City of London  Croydon    Ealing   Enfield  ...    Merton   Newham  \
# 0         5.30162   4.2011  4.311451  4.263472  ...  4.741273  5.30539
#
#    Redbridge  Richmond upon Thames  Southwark    Sutton  Tower Hamlets  \
# 0   4.471182              4.005162   5.516485  4.118523       4.626701
#
#    Waltham Forest  Wandsworth  Westminster
# 0        5.834756    4.757709     5.353565
#
# [1 rows x 33 columns]

# %%
df_ratios_T = df_ratios.T
df_ratios = df_ratios_T.reset_index()
df_ratios.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
df_ratios.rename(columns={'index':'Borough', 0:'2018'}, inplace=True)
df_ratios.head()
# Out:
#               Borough      2018
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
top15 = df_ratios.sort_values(by='2018',ascending=False).head(15)
print(top15)
# Out:
#                  Borough      2018
# 11               Hackney  6.198286
# 30        Waltham Forest  5.834756
# 27             Southwark  5.516485
# 22              Lewisham  5.449221
# 32           Westminster  5.353565
# 24                Newham  5.305390
# 6         City of London  5.301620
# 13              Haringey  5.134625
# 19  Kensington & Chelsea  5.082465
# 21               Lambeth  4.957751
# 5                 Camden  4.935353
# 0     Barking & Dagenham  4.896619
# 3                  Brent  4.894554
# 18             Islington  4.844048
# 10             Greenwich  4.763036

# %%
ax = top15[['Borough','2018']].plot(kind='bar')
ax.set_xticklabels(top15.Borough)
# Out:
# [Text(0, 0, 'Hackney'),
#  Text(1, 0, 'Waltham Forest'),
#  Text(2, 0, 'Southwark'),
#  Text(3, 0, 'Lewisham'),
#  Text(4, 0, 'Westminster'),
#  Text(5, 0, 'Newham'),
#  Text(6, 0, 'City of London'),
#  Text(7, 0, 'Haringey'),
#  Text(8, 0, 'Kensington & Chelsea'),
#  Text(9, 0, 'Lambeth'),
#  Text(10, 0, 'Camden'),
#  Text(11, 0, 'Barking & Dagenham'),
#  Text(12, 0, 'Brent'),
#  Text(13, 0, 'Islington'),
#  Text(14, 0, 'Greenwich')]

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!
#
# ### Which borough of London has seen the greatest average increase in housing prices over the (approximately) two decades covered by the dataset?
#
# Answer: Of the 32 Boroughs of London, the Borough that saw the greatest average increase in housing prices between 1998 and 2018 was Hackney, followed by Waltham Forest, Southwark, Lewisham, and Westminster.
